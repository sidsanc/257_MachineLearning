# %% [markdown]
# ## Import standard packages and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import time
from datetime import datetime

import matplotlib.ticker as mtick
from matplotlib.ticker import FuncFormatter
from sklearn.metrics import mean_squared_error
from scipy import linalg
import matplotlib as mpl

from sklearn import mixture

# import warnings
# from sklearn.utils.testing import ignore_warnings
# from sklearn.exceptions import ConvergenceWarning
# warnings.filterwarnings('ignore')

# %%
url = 'https://drive.google.com/file/d/1HfTP590blvZIYS3MhlQyZK3or4lgIGaV/view'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
data = pd.read_csv(url)
data.head()
# data = pd.read_csv("/content/Zip_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv")
# data.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91940         0       77449        zip        TX    TX       NaN
# 1     91982         1       77494        zip        TX    TX       NaN
# 2     93144         2       79936        zip        TX    TX   El Paso
# 3     62080         3       11368        zip        NY    NY  New York
# 4     62093         4       11385        zip        NY    NY  New York
#
#                                    Metro        CountyName  2000-01-31  ...  \
# 0   Houston-The Woodlands-Sugar Land, TX     Harris County     96603.0  ...
# 1   Houston-The Woodlands-Sugar Land, TX  Fort Bend County    163540.0  ...
# 2                            El Paso, TX    El Paso County     87170.0  ...
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County    324450.0  ...
# 4  New York-Newark-Jersey City, NY-NJ-PA     Queens County    279395.0  ...
#
#    2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# 0    232376.0    236021.0    239693.0    244103.0    249528.0    255561.0
# 1    330128.0    334969.0    339733.0    346806.0    355476.0    365971.0
# 2    167760.0    169442.0    171444.0    173448.0    175569.0    178832.0
# 3    814606.0    815163.0    817786.0    818496.0    823195.0    827059.0
# 4    749033.0    750202.0    754601.0    758353.0    764191.0    766694.0
#
#    2022-05-31  2022-06-30  2022-07-31  2022-08-31
# 0    261406.0    266140.0    269363.0    271087.0
# 1    374539.0    379908.0    381471.0    380327.0
# 2    182377.0    185780.0    188090.0    189856.0
# 3    836542.0    842837.0    849412.0    852484.0
# 4    772804.0    778368.0    783167.0    785138.0
#
# [5 rows x 281 columns]

# %% [markdown]
# We will drop 'StateName' and 'RegionType' due to redundancy, and 'SizeRank' due to it being irrelevant for analysis.

# %%
# Drop unnecessary columns 
data = data.drop(['RegionID', 'StateName', 'RegionType', 'SizeRank'], axis=1)

# Change name of 'RegionName' to 'ZipCode'
data = data.rename(columns={'RegionName': 'ZipCode'})

# %%
data.isna().sum().sum()
# Out:
# 1644543

# %%
data.shape
# Out:
# (23404, 277)

# %% [markdown]
# ## Analyze 'ZipCode'

# %% [markdown]
# Next we will look at RegionName, this is the zip code.

# %%
data.ZipCode.value_counts()
# Out:
# 77449    1
# 35203    1
# 39464    1
# 71430    1
# 17505    1
#         ..
# 25401    1
# 74344    1
# 6120     1
# 33301    1
# 50160    1
# Name: ZipCode, Length: 23404, dtype: int64

# %% [markdown]
# All zipcodes are unique. Changing to string

# %%
data.ZipCode = data.ZipCode.astype('string')

# %%
data[['ZipCode', 'State']].sort_values(by=['ZipCode'])
# Out:
#       ZipCode State
# 4646    10001    NY
# 137     10002    NY
# 655     10003    NY
# 11591   10005    NY
# 9650    10007    NY
# ...       ...   ...
# 3676    99709    AK
# 7046    99712    AK
# 4183    99801    AK
# 16770   99824    AK
# 7997    99901    AK
#
# [23404 rows x 2 columns]

# %%
data.ZipCode.count()
# Out:
# 23404

# %% [markdown]
# ## Analyze 'City'

# %%
data.City.nunique()
# Out:
# 11311

# %%
data.City.isna().sum()
# Out:
# 1085

# %%
data.City.fillna('None', inplace=True)

# %% [markdown]
# ## Analyze 'Metro'

# %% [markdown]
# Fillna with None

# %%
print(data.Metro.value_counts())
print(data.Metro.nunique())
# Out:
# New York-Newark-Jersey City, NY-NJ-PA           793
# Chicago-Naperville-Elgin, IL-IN-WI              368
# Los Angeles-Long Beach-Anaheim, CA              355
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD     316
# Washington-Arlington-Alexandria, DC-VA-MD-WV    292
#                                                ...
# Lamesa, TX                                        1
# Connersville, IN                                  1
# Portales, NM                                      1
# Natchitoches, LA                                  1
# Hereford, TX                                      1
# Name: Metro, Length: 922, dtype: int64
# 922

# %%
data.Metro.fillna('None', inplace=True)

# %%
data.Metro.value_counts()
# Out:
# None                                           4206
# New York-Newark-Jersey City, NY-NJ-PA           793
# Chicago-Naperville-Elgin, IL-IN-WI              368
# Los Angeles-Long Beach-Anaheim, CA              355
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD     316
#                                                ...
# Zapata, TX                                        1
# Craig, CO                                         1
# Clovis, NM                                        1
# Butte-Silver Bow, MT                              1
# Natchitoches, LA                                  1
# Name: Metro, Length: 923, dtype: int64

# %% [markdown]
# ## Analyze 'CountyName'

# %%
data.CountyName.value_counts()
# Out:
# Washington County     275
# Los Angeles County    268
# Jefferson County      260
# Montgomery County     215
# Franklin County       201
#                      ...
# Lanier County           1
# Catahoula Parish        1
# Brewster County         1
# Early County            1
# McCone County           1
# Name: CountyName, Length: 1705, dtype: int64

# %%
data.isna().sum()
# Out:
# ZipCode         0
# State           0
# City            0
# Metro           0
# CountyName      0
#              ...
# 2022-04-30    279
# 2022-05-31    238
# 2022-06-30    157
# 2022-07-31     85
# 2022-08-31     12
# Length: 277, dtype: int64

# %%
data.CountyName.fillna('None', inplace=True)

# %% [markdown]
# ## Drop sales data that have missing values

# %%
data[data['2000-01-31'].isna()]
# Out:
#       ZipCode State          City                                  Metro  \
# 29      94565    CA     Pittsburg     San Francisco-Oakland-Berkeley, CA
# 32      78521    TX   Brownsville              Brownsville-Harlingen, TX
# 41      10456    NY      New York  New York-Newark-Jersey City, NY-NJ-PA
# 44      11219    NY      New York  New York-Newark-Jersey City, NY-NJ-PA
# 50      77573    TX   League City   Houston-The Woodlands-Sugar Land, TX
# ...       ...   ...           ...                                    ...
# 23399   46799    IN    Zanesville                           Bluffton, IN
# 23400   77451    TX  East Bernard   Houston-The Woodlands-Sugar Land, TX
# 23401   14441    NY       Dresden                          Rochester, NY
# 23402   26576    WV    Farmington                           Fairmont, WV
# 23403   50160    IA   Martensdale         Des Moines-West Des Moines, IA
#
#                 CountyName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  \
# 29     Contra Costa County         NaN         NaN         NaN         NaN
# 32          Cameron County         NaN         NaN         NaN         NaN
# 41            Bronx County         NaN         NaN         NaN         NaN
# 44            Kings County         NaN         NaN         NaN         NaN
# 50        Galveston County         NaN         NaN         NaN         NaN
# ...                    ...         ...         ...         ...         ...
# 23399         Wells County         NaN         NaN         NaN         NaN
# 23400     Fort Bend County         NaN         NaN         NaN         NaN
# 23401         Yates County         NaN         NaN         NaN         NaN
# 23402        Marion County         NaN         NaN         NaN         NaN
# 23403        Warren County         NaN         NaN         NaN         NaN
#
#        2000-05-31  ...  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# 29            NaN  ...    563088.0    568049.0    578143.0    584834.0
# 32            NaN  ...    141332.0    143702.0    145785.0    148925.0
# 41            NaN  ...    458589.0    463623.0    470458.0    474277.0
# 44            NaN  ...    829604.0    828789.0    828065.0    830625.0
# 50            NaN  ...    290825.0    294876.0    297864.0    301136.0
# ...           ...  ...         ...         ...         ...         ...
# 23399         NaN  ...    157257.0    160065.0    162584.0    165641.0
# 23400         NaN  ...         NaN         NaN         NaN         NaN
# 23401         NaN  ...         NaN         NaN         NaN         NaN
# 23402         NaN  ...     86012.0     87789.0     89386.0     91390.0
# 23403         NaN  ...    172528.0    175198.0    179559.0    182863.0
#
#        2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31
# 29       594957.0    602028.0    602774.0    597243.0    589975.0    584882.0
# 32       151875.0    155071.0    157557.0    160752.0    163829.0    167074.0
# 41       475801.0    478393.0    480640.0    484812.0    484884.0    488002.0
# 44       836662.0    843739.0    849336.0    853506.0    857684.0    864057.0
# 50       305735.0    312295.0    317528.0    320674.0    321755.0    323265.0
# ...           ...         ...         ...         ...         ...         ...
# 23399    166776.0    168208.0    169037.0    170919.0    172515.0    174173.0
# 23400         NaN         NaN    211125.0    211719.0    210235.0    205233.0
# 23401         NaN         NaN         NaN         NaN    147462.0    149161.0
# 23402     91966.0     93260.0     94337.0     95119.0     95557.0     95880.0
# 23403    183721.0    184710.0    185861.0    188514.0    190280.0    191809.0
#
# [11803 rows x 277 columns]

# %%
# All zipcodes have some data
data[data['2022-06-30'].isna()]
# Out:
#       ZipCode State              City                                  Metro  \
# 1057    11237    NY          New York  New York-Newark-Jersey City, NY-NJ-PA
# 5727    37857    TN       Rogersville               Kingsport-Bristol, TN-VA
# 8071    74003    OK      Bartlesville                       Bartlesville, OK
# 10647   62201    IL  East Saint Louis                       St. Louis, MO-IL
# 11097   28128    NC           Norwood                          Albemarle, NC
# ...       ...   ...               ...                                    ...
# 23391   45032    OH       Harveysburg                   Cincinnati, OH-KY-IN
# 23393   95419    CA       Camp Meeker                Santa Rosa-Petaluma, CA
# 23396   98628    WA        Goldendale                                   None
# 23397   98522    WA          Chehalis                          Centralia, WA
# 23401   14441    NY           Dresden                          Rochester, NY
#
#                CountyName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  \
# 1057         Kings County         NaN         NaN         NaN         NaN
# 5727       Hawkins County     73133.0     73542.0     73512.0     73770.0
# 8071    Washington County     49969.0     49995.0     50338.0     50749.0
# 10647  Saint Clair County         NaN         NaN         NaN         NaN
# 11097       Stanly County    150767.0    151217.0    151680.0    152798.0
# ...                   ...         ...         ...         ...         ...
# 23391       Warren County         NaN         NaN         NaN         NaN
# 23393       Sonoma County         NaN         NaN         NaN         NaN
# 23396    Klickitat County         NaN         NaN         NaN         NaN
# 23397        Lewis County         NaN         NaN         NaN         NaN
# 23401        Yates County         NaN         NaN         NaN         NaN
#
#        2000-05-31  ...  2021-11-30  2021-12-31  2022-01-31  2022-02-28  \
# 1057          NaN  ...         NaN         NaN         NaN         NaN
# 5727      73636.0  ...    152657.0    155458.0    157304.0    160452.0
# 8071      51328.0  ...     95618.0     97502.0     99215.0    101107.0
# 10647         NaN  ...         NaN         NaN         NaN         NaN
# 11097    153793.0  ...    282503.0    286983.0    291784.0    296154.0
# ...           ...  ...         ...         ...         ...         ...
# 23391         NaN  ...         NaN         NaN         NaN         NaN
# 23393         NaN  ...         NaN         NaN         NaN         NaN
# 23396         NaN  ...         NaN         NaN         NaN         NaN
# 23397         NaN  ...         NaN         NaN         NaN         NaN
# 23401         NaN  ...         NaN         NaN         NaN         NaN
#
#        2022-03-31  2022-04-30  2022-05-31  2022-06-30  2022-07-31  2022-08-31
# 1057          NaN         NaN         NaN         NaN         NaN   1133842.0
# 5727     162559.0    166128.0    171648.0         NaN    186733.0    192806.0
# 8071     102623.0    104657.0    106346.0         NaN    103021.0    101139.0
# 10647         NaN         NaN         NaN         NaN     65833.0     67697.0
# 11097    298957.0         NaN         NaN         NaN         NaN    230328.0
# ...           ...         ...         ...         ...         ...         ...
# 23391         NaN         NaN         NaN         NaN         NaN    200021.0
# 23393         NaN         NaN         NaN         NaN    633246.0    620842.0
# 23396         NaN         NaN         NaN         NaN    139024.0    140818.0
# 23397         NaN         NaN         NaN         NaN    572066.0    574933.0
# 23401         NaN         NaN         NaN         NaN    147462.0    149161.0
#
# [157 rows x 277 columns]

# %%
def melt_data(data):
    melted = pd.melt(data,
                     id_vars=['ZipCode', 'State', 'City', 'Metro', 'CountyName'],
                     var_name='Date')
    melted['Date'] = pd.to_datetime(melted['Date'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted

# %%
melted_data = melt_data(data)
melted_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4726636 entries, 0 to 6365887
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ZipCode     string
#  1   State       object
#  2   City        object
#  3   Metro       object
#  4   CountyName  object
#  5   Date        datetime64[ns]
#  6   value       float64
# dtypes: datetime64[ns](1), float64(1), object(4), string(1)
# memory usage: 288.5+ MB

# %%
# Make sure the data type of the 'Date' column is datetime
melted_data['Date'] = pd.to_datetime(melted_data['Date'], format='%Y/%m')

# Set the 'Date' columns as index
melted_data.set_index('Date', inplace=True)

melted_data.info
# Out:
# <bound method DataFrame.info of            ZipCode State          City                                  Metro  \
# Date
# 2000-01-31   77449    TX          None   Houston-The Woodlands-Sugar Land, TX
# 2000-01-31   77494    TX          None   Houston-The Woodlands-Sugar Land, TX
# 2000-01-31   79936    TX       El Paso                            El Paso, TX
# 2000-01-31   11368    NY      New York  New York-Newark-Jersey City, NY-NJ-PA
# 2000-01-31   11385    NY      New York  New York-Newark-Jersey City, NY-NJ-PA
# ...            ...   ...           ...                                    ...
# 2022-08-31   46799    IN    Zanesville                           Bluffton, IN
# 2022-08-31   77451    TX  East Bernard   Houston-The Woodlands-Sugar Land, TX
# 2022-08-31   14441    NY       Dresden                          Rochester, NY
# 2022-08-31   26576    WV    Farmington                           Fairmont, WV
# 2022-08-31   50160    IA   Martensdale         Des Moines-West Des Moines, IA
#
#                   CountyName     value
# Date
# 2000-01-31     Harris County   96603.0
# 2000-01-31  Fort Bend County  163540.0
# 2000-01-31    El Paso County   87170.0
# 2000-01-31     Queens County  324450.0
# 2000-01-31     Queens County  279395.0
# ...                      ...       ...
# 2022-08-31      Wells County  174173.0
# 2022-08-31  Fort Bend County  205233.0
# 2022-08-31      Yates County  149161.0
# 2022-08-31     Marion County   95880.0
# 2022-08-31     Warren County  191809.0
#
# [4726636 rows x 6 columns]>

# %%
melted_data.head()
# Out:
#            ZipCode State      City                                  Metro  \
# Date
# 2000-01-31   77449    TX      None   Houston-The Woodlands-Sugar Land, TX
# 2000-01-31   77494    TX      None   Houston-The Woodlands-Sugar Land, TX
# 2000-01-31   79936    TX   El Paso                            El Paso, TX
# 2000-01-31   11368    NY  New York  New York-Newark-Jersey City, NY-NJ-PA
# 2000-01-31   11385    NY  New York  New York-Newark-Jersey City, NY-NJ-PA
#
#                   CountyName     value
# Date
# 2000-01-31     Harris County   96603.0
# 2000-01-31  Fort Bend County  163540.0
# 2000-01-31    El Paso County   87170.0
# 2000-01-31     Queens County  324450.0
# 2000-01-31     Queens County  279395.0

# %% [markdown]
# ## EDA on ZipCodes

# %%
print('Average home value' ,round(data['2022-08-31'].mean()))
# Out:
# Average home value 346470

# %%
#Average Home Value by Month and Year
month_data = melted_data['value'].resample('MS').mean()
month_data = month_data.fillna(month_data.bfill())
month_data.plot(figsize=(12,5), color='red')
plt.title('Average Home Value By Month')
plt.ylabel('Value')
plt.show()

# %%
yr_data = melted_data['value'].resample('A').mean()
yr_data.plot.line(figsize=(12,5), color='orange')
plt.title('Average Home Value By Year')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ## Top 10 Metro and County (mean)

# %%
# Get Mean Home Value by metro
metro = melted_data.groupby('Metro')
metro = metro.value.mean()
metro = metro.sort_values(ascending=False).head(10)

# Plot Mean Home Value by Metro
metro.plot.barh(figsize=(12,7), color='blue')
plt.title('10-Year Mean Value by Metro')
plt.xlabel('Value in Millions of Dollars ($)')
plt.show()

# %%
# Get Mean Home Value by County
county = melted_data.groupby('CountyName')
county = county.value.mean()
county = county.sort_values(ascending=False).head(10)

# Plot Mean Home Value by County
county.plot.barh(figsize = (12,7), color='darkgreen')
plt.title('10-Year Mean Value by County')
plt.xlabel('Value in Millions of Dollars ($)')
plt.ylabel('County Name')
plt.show()

# %% [markdown]
# ## Most recent one year ROI

# %%
# Check out most recent 1 year ROI
data['recent_1_yr_ROI'] = (data['2022-08-31'] - data['2021-08-31'])/(data['2021-08-31'])
data['recent_1_yr_ROI']
# Out:
# 0        0.232488
# 1        0.219513
# 2        0.182189
# 3        0.056239
# 4        0.063654
#            ...
# 23399    0.132435
# 23400         NaN
# 23401         NaN
# 23402    0.129528
# 23403    0.170195
# Name: recent_1_yr_ROI, Length: 23404, dtype: float64

# %%
# Lowest Values
data.sort_values('recent_1_yr_ROI').head()[['ZipCode', 'City', 'recent_1_yr_ROI']]
# Out:
#        ZipCode         City  recent_1_yr_ROI
# 10302    32626    Chiefland        -0.159863
# 11097    28128      Norwood        -0.156950
# 12943    32621      Bronson        -0.155968
# 10441    63120  Saint Louis        -0.145128
# 20261    41776       Wooton        -0.143996

# %%
# Highest Values 
data.sort_values('recent_1_yr_ROI', ascending=False).head()[['ZipCode', 'City', 'recent_1_yr_ROI']]
# Out:
#        ZipCode            City  recent_1_yr_ROI
# 11610    44627  Fredericksburg         0.670043
# 10427    44606     Apple Creek         0.604589
# 8815     34102          Naples         0.575952
# 12518    44676          Shreve         0.575068
# 6636     34114          Naples         0.547776

# %%
def average_one_year_ROI(data):
    average_one_year_ROI = []
    for i in range(len(data)):
        year_1_ROI = data['recent_1_yr_ROI'][i]
        year_2_ROI = (data.iloc[i,-15] - data.iloc[i,-27])/data.iloc[i,-27]
        year_3_ROI = (data.iloc[i,-27] - data.iloc[i,-39])/data.iloc[i,-39]
        avg_ROI = (year_1_ROI + year_2_ROI + year_3_ROI)/3
        average_one_year_ROI.append(avg_ROI)
    return average_one_year_ROI

# %%
data['avg_one_yr_ROI'] = average_one_year_ROI(data)

# %%
data_top = data[(data['2022-08-31'] < 100000) & (data['avg_one_yr_ROI'] > 0.20)]
data_top
# Out:
#        ZipCode State           City  \
# 1067     48219    MI        Detroit
# 2513     48601    MI        Saginaw
# 2879     19132    PA   Philadelphia
# 3725     45417    OH         Dayton
# 4336     31206    GA          Macon
# 4554     43605    OH         Toledo
# 4576     48238    MI        Detroit
# 4716     38114    TN        Memphis
# 4807     35020    AL       Bessemer
# 4967     38106    TN        Memphis
# 4998     46806    IN     Fort Wayne
# 5354     14211    NY        Buffalo
# 5552     43609    OH         Toledo
# 5731     44108    OH      Cleveland
# 5757     48505    MI          Flint
# 5892      8104    NJ         Camden
# 6359     63115    MO    Saint Louis
# 6415     45406    OH         Dayton
# 6442     38108    TN        Memphis
# 6546     45405    OH         Dayton
# 6562     46016    IN       Anderson
# 6574     46404    IN           Gary
# 6746     17401    PA           York
# 6800     40212    KY     Louisville
# 7156     19602    PA        Reading
# 7328     31217    GA            NaN
# 7452     67214    KS        Wichita
# 7523     35208    AL     Birmingham
# 7564     44485    OH         Warren
# 7900     45403    OH         Dayton
# 8275     40210    KY     Louisville
# 8417     14301    NY  Niagara Falls
# 8717     44509    OH     Youngstown
# 9034     36110    AL     Montgomery
# 9187     45402    OH         Dayton
# 9273     46613    IN     South Bend
# 17157     50829.0     50465.0         0.179419        0.212323
# 21551     81386.0     81943.0         0.251764        0.202163
# 21972     91075.0     93331.0         0.526163        0.209278
#
# [49 rows x 279 columns]

# %%
data_top[['ZipCode', 'City','State','Metro','2022-08-31','avg_one_yr_ROI']]
# Out:
#        ZipCode           City State  \
# 1067     48219        Detroit    MI
# 2513     48601        Saginaw    MI
# 2879     19132   Philadelphia    PA
# 3725     45417         Dayton    OH
# 4336     31206          Macon    GA
# 4554     43605         Toledo    OH
# 4576     48238        Detroit    MI
# 4716     38114        Memphis    TN
# 4807     35020       Bessemer    AL
# 4967     38106        Memphis    TN
# 4998     46806     Fort Wayne    IN
# 5354     14211        Buffalo    NY
# 5552     43609         Toledo    OH
# 5731     44108      Cleveland    OH
# 5757     48505          Flint    MI
# 5892      8104         Camden    NJ
# 6359     63115    Saint Louis    MO
# 6415     45406         Dayton    OH
# 6442     38108        Memphis    TN
# 6546     45405         Dayton    OH
# 6562     46016       Anderson    IN
# 6574     46404           Gary    IN
# 6746     17401           York    PA
# 6800     40212     Louisville    KY
# 7156     19602        Reading    PA
# 7328     31217            NaN    GA
# 7452     67214        Wichita    KS
# 7523     35208     Birmingham    AL
# 7564     44485         Warren    OH
# 7900     45403         Dayton    OH
# 8275     40210     Louisville    KY
# 8417     14301  Niagara Falls    NY
# 8717     44509     Youngstown    OH
# 9034     36110     Montgomery    AL
# 9187     45402         Dayton    OH
# 9273     46613     South Bend    IN
# 9682     44502     Youngstown    OH
# 9807     35204     Birmingham    AL
# 10980    48218    River Rouge    MI
# 11073    35218     Birmingham    AL
# 11457    44307          Akron    OH
# 12703    14303  Niagara Falls    NY
# 12949    44507     Youngstown    OH
# 13773    44504     Youngstown    OH
# 13972    17954    Minersville    PA
# 16731    17970    Saint Clair    PA
# 17157    44510     Youngstown    OH
# 21551    26137            NaN    WV
# 21972    29320    Spartanburg    SC
#
#                                              Metro  2022-08-31  avg_one_yr_ROI
# 1067                   Detroit-Warren-Dearborn, MI     85091.0        0.211613
# 2513                                   Saginaw, MI     66539.0        0.217973
# 2879   Philadelphia-Camden-Wilmington, PA-NJ-DE-MD     91530.0        0.254554
# 3725                          Dayton-Kettering, OH     64722.0        0.200708
# 4336                         Macon-Bibb County, GA     70769.0        0.238537
# 4554                                    Toledo, OH     50093.0        0.211947
# 4576                   Detroit-Warren-Dearborn, MI     57141.0        0.202534
# 4716                             Memphis, TN-MS-AR     95504.0        0.285365
# 4807                         Birmingham-Hoover, AL     78050.0        0.222329
# 4967                             Memphis, TN-MS-AR     64812.0        0.232560
# 4998                                Fort Wayne, IN     94945.0        0.204007
# 5354                       Buffalo-Cheektowaga, NY     88251.0        0.207394
# 5552                                    Toledo, OH     63701.0        0.231705
# 5731                          Cleveland-Elyria, OH     56332.0        0.224084
# 5757                                     Flint, MI     28358.0        0.221992
# 5892   Philadelphia-Camden-Wilmington, PA-NJ-DE-MD     95413.0        0.330671
# 6359                              St. Louis, MO-IL     45227.0        0.285664
# 6415                          Dayton-Kettering, OH     88169.0        0.218485
# 20    617099.0    622755.0    629299.0    636907.0    647077.0    657858.0
#
#     2022-05-31  2022-06-30      Y
# 0     261406.0    266140.0  77449
# 1     374539.0    379908.0  77494
# 2     182377.0    185780.0  79936
# 6     263459.0    265572.0  60629
# 7     252703.0    256619.0  77084
# 8     711423.0    712829.0  91331
# 9     702447.0    705918.0  90650
# 10    528628.0    538842.0   8701
# 12    630980.0    634574.0  90201
# 13    533159.0    538622.0  92335
# 14    666651.0    672632.0  11208
# 17    462620.0    458565.0  78660
# 18    592929.0    595989.0  92503
# 19    885916.0    885440.0  90250
# 20    667033.0    668060.0  90044
#
# [15 rows x 271 columns]

# %%
from sklearn.model_selection import train_test_split
train_df_y = train_df['Y']
train_df = train_df.drop('Y', axis = 1)
X_train, X_test, Y_train, Y_test = train_test_split(train_df,train_df_y, test_size=0.33, random_state=4)

# %% [markdown]
# # Fractal Clustering

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.cluster import KMeans
from sklearn import metrics

# %%
def plot_cluster(data, max_loop=50):
    try:
        data.drop('cluster', axis=1, inplace=True)
    except:
        next
    X = data.iloc[:,1:]
    rb = RobustScaler()
    X_rb = rb.fit_transform(X)
    
    sse_within_cluster = {}
    silhouette_score = {}
    
    for k in range(2, max_loop):
        kmeans = KMeans(n_clusters=k,  random_state=10, n_init=10)
        kmeans.fit(X_rb)
        sse_within_cluster[k] = kmeans.inertia_
        silhouette_score[k] = metrics.silhouette_score(X_rb, kmeans.labels_, random_state=10)

    _ = plt.figure(figsize=(10,6))
    ax1 = plt.subplot(211)
    _ = plt.plot(list(sse_within_cluster.keys()), list(sse_within_cluster.values()))
    _ = plt.xlabel("Number of Clusters")
    _ = plt.ylabel("SSE Within Cluster")
    _ = plt.title("Within Cluster SSE After K-Means Clustering")
    _ = plt.xticks([i for i in range(2, max_loop)], rotation=75)
    
    ax2 = plt.subplot(212)
    _ = plt.plot(list(silhouette_score.keys()), list(silhouette_score.values()))
    _ = plt.xlabel("Number of Clusters")
    _ = plt.ylabel("Silhouette Score")
    _ = plt.title("Silhouette Score After K-Means Clustering")
    _ = plt.xticks([i for i in range(2, max_loop)], rotation=75)
    
    plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.5, wspace=0.35)

# %%
def apply_cluster(df, clusters=2):
    try:
        df.drop('cluster', axis=1, inplace=True)
    except:
        next
    X = df.iloc[:,1:]
    rb = RobustScaler()
    X_rb = rb.fit_transform(X)
    kmeans = KMeans(n_clusters=clusters, random_state=10, n_init=10)  
    kmeans.fit(X_rb) 
    score = metrics.silhouette_score(X_rb, kmeans.labels_, random_state=10)
    df['cluster'] = kmeans.labels_
    sse_within_cluster = kmeans.inertia_
    
    print("clustering performance")
    print("#############################")
    print("silhouette score: " + str(score.round(2)))
    print("sse withing cluster: " + str(sse_within_cluster))
    
    return df

# %%
change_df = data.iloc[:, 5:275]
change_df = change_df.pct_change(axis=1)

# %%
change_df['Mean'] = change_df.mean(axis = 1).round(decimals = 3)
change_df.head()
# Out:
#    2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  2000-06-30  \
# 0         NaN    0.000155   -0.001760    0.000218    0.000580    0.001616
# 1         NaN    0.001529    0.001612    0.004157   -0.000874   -0.001428
# 2         NaN    0.000700    0.000573    0.000206    0.000641    0.000034
# 3         NaN    0.012239    0.008154    0.013035    0.009314    0.009376
# 4         NaN    0.003304    0.005237    0.006267    0.004140    0.003375
#
#    2000-07-31  2000-08-31  2000-09-30  2000-10-31  ...  2021-10-31  \
# 0    0.000952    0.001478    0.003642    0.002323  ...    0.019338
# 1   -0.006510   -0.001213   -0.003470    0.002664  ...    0.018864
# 2   -0.000034   -0.000389   -0.006230   -0.007237  ...    0.014312
# 3    0.012232    0.011287    0.011069    0.012919  ...    0.002325
# 4    0.002380    0.009690    0.008719    0.013125  ...    0.004843
#
#    2021-11-30  2021-12-31  2022-01-31  2022-02-28  2022-03-31  2022-04-30  \
# 0    0.014122    0.015686    0.015558    0.018399    0.022224    0.024178
# 1    0.017676    0.014664    0.014222    0.020819    0.025000    0.029524
# 2    0.011986    0.010026    0.011815    0.011689    0.012228    0.018585
# 3    0.003475    0.000684    0.003218    0.000868    0.005741    0.004694
# 4    0.005561    0.001561    0.005864    0.004972    0.007698    0.003275
#
#    2022-05-31  2022-06-30   Mean
# 0    0.022871    0.018110  0.004
# 1    0.023412    0.014335  0.003
# 2    0.019823    0.018659  0.003
# 3    0.011466    0.007525  0.004
# 4    0.007969    0.007200  0.004
#
# [5 rows x 271 columns]

# %%
change_df['Mean'].value_counts().plot.pie()

# %%
change_df_train = change_df.iloc[:,1:].dropna().drop('Mean',axis=1)

# %%
plot_cluster(train_df, max_loop=25)

# %% [markdown]
# Optimal Cluster  = 3

# %%
first_trial = apply_cluster(change_df_train, clusters=3)
# Out:
# clustering performance
# #############################
# silhouette score: 0.06
# sse withing cluster: 2594193.480335761

# %%
cluster_perf_df = first_trial.groupby('cluster')
cluster_perf_df['cluster'].value_counts()
# Out:
# cluster  cluster
# 0        0          5872
# 1        1          3431
# 2        2          2298
# Name: cluster, dtype: int64

# %%
colors = ['#DF2020', '#81DF20', '#2095DF']
first_trial['c'] = first_trial.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})
first_trial['Y'] = data['ZipCode']
first_trial.head()
# Out:
#    2000-02-29  2000-03-31  2000-04-30  2000-05-31  2000-06-30  2000-07-31  \
# 0    0.000155   -0.001760    0.000218    0.000580    0.001616    0.000952
# 1    0.001529    0.001612    0.004157   -0.000874   -0.001428   -0.006510
# 2    0.000700    0.000573    0.000206    0.000641    0.000034   -0.000034
# 3    0.012239    0.008154    0.013035    0.009314    0.009376    0.012232
# 4    0.003304    0.005237    0.006267    0.004140    0.003375    0.002380
#
#    2000-08-31  2000-09-30  2000-10-31  2000-11-30  ...  2021-12-31  \
# 0    0.001478    0.003642    0.002323    0.004923  ...    0.015686
# 1   -0.001213   -0.003470    0.002664    0.004161  ...    0.014664
# 2   -0.000389   -0.006230   -0.007237   -0.010656  ...    0.010026
# 3    0.011287    0.011069    0.012919    0.013832  ...    0.000684
# 4    0.009690    0.008719    0.013125    0.009625  ...    0.001561
#
#    2022-01-31  2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  \
# 0    0.015558    0.018399    0.022224    0.024178    0.022871    0.018110
# 1    0.014222    0.020819    0.025000    0.029524    0.023412    0.014335
# 2    0.011815    0.011689    0.012228    0.018585    0.019823    0.018659
# 3    0.003218    0.000868    0.005741    0.004694    0.011466    0.007525
# 4    0.005864    0.004972    0.007698    0.003275    0.007969    0.007200
#
#    cluster        c      Y
# 0        0  #DF2020  77449
# 1        0  #DF2020  77494
# 2        0  #DF2020  79936
# 3        1  #81DF20  11368
# 4        1  #81DF20  11385
#
# [5 rows x 272 columns]

# %%
plt.scatter(first_trial['2000-02-29'], first_trial['2022-06-30'],c=first_trial.c, alpha = 0.6, s=10)

# %% [markdown]
# #### Second Iteration

# %%
df3 = first_trial.query("cluster == 0").reset_index(drop=True).drop(['c', 'Y'], axis=1)

# %%
plot_cluster(df3, max_loop=25)

# %% [markdown]
# **Optimal Cluster** is 3.

# %%
second_trial= apply_cluster(df3, clusters=3)
# Out:
# clustering performance
# #############################
# silhouette score: 0.04
# sse withing cluster: 1926939.3814955656

# %%
cluster_perf_df = second_trial.groupby('cluster')
cluster_perf_df['cluster'].value_counts()
# Out:
# cluster  cluster
# 0        0           831
# 1        1          3441
# 2        2          1600
# Name: cluster, dtype: int64

# %%
colors = ['#FFFFFF', '#3cb44b','#FFFFFF']
second_trial['c'] = second_trial.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})
second_trial['Y'] = data['ZipCode']
second_trial.head()
# Out:
#    2000-02-29  2000-03-31  2000-04-30  2000-05-31  2000-06-30  2000-07-31  \
# 0    0.000155   -0.001760    0.000218    0.000580    0.001616    0.000952
# 1    0.001529    0.001612    0.004157   -0.000874   -0.001428   -0.006510
# 2    0.000700    0.000573    0.000206    0.000641    0.000034   -0.000034
# 3   -0.000455   -0.002537   -0.000654   -0.000384    0.001663    0.000291
# 4    0.002971    0.002067    0.007939    0.010005    0.013683    0.011767
#
#    2000-08-31  2000-09-30  2000-10-31  2000-11-30  ...  2021-12-31  \
# 0    0.001478    0.003642    0.002323    0.004923  ...    0.015686
# 1   -0.001213   -0.003470    0.002664    0.004161  ...    0.014664
# 2   -0.000389   -0.006230   -0.007237   -0.010656  ...    0.010026
# 3    0.001494    0.003563    0.003323    0.005668  ...    0.014534
# 4    0.010640    0.004872    0.003973    0.001427  ...   -0.004601
#
#    2022-01-31  2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  \
# 0    0.015558    0.018399    0.022224    0.024178    0.022871    0.018110
# 1    0.014222    0.020819    0.025000    0.029524    0.023412    0.014335
# 2    0.011815    0.011689    0.012228    0.018585    0.019823    0.018659
# 3    0.014317    0.016092    0.019614    0.020770    0.020210    0.015496
# 4    0.000594    0.001860    0.004760    0.004271    0.004054    0.002986
#
#    cluster        c      Y
# 0        2  #FFFFFF  77449
# 1        1  #3cb44b  77494
# 2        1  #3cb44b  79936
# 3        2  #FFFFFF  11368
# 4        0  #FFFFFF  11385
#
# [5 rows x 272 columns]

# %%
plt.scatter(second_trial['2000-02-29'], second_trial['2022-06-30'],c=second_trial.c, alpha = 0.6, s=10)

# %% [markdown]
# After the second iteration we again found two prominent clusters, thus we will dive deeper and perform a third iteration on the more prominent cluster.

# %% [markdown]
# #### Third Iteration

# %%
df4 = second_trial.query("cluster == 1").reset_index(drop=True).drop(['c', 'Y'], axis=1)

# %%
plot_cluster(df4, max_loop=25)

# %% [markdown]
# **Optimal Cluster** is 3.

# %%
third_trial = apply_cluster(df4, clusters=3)
# Out:
# clustering performance
# #############################
# silhouette score: 0.02
# sse withing cluster: 1331352.0741808838

# %%
cluster_perf_df = third_trial.groupby('cluster')
cluster_perf_df['cluster'].value_counts()
# Out:
# cluster  cluster
# 0        0            24
# 1        1          1739
# 2        2          1678
# Name: cluster, dtype: int64

# %%
colors = ['#e6194b', '#3cb44b', '#2095DF' ]
third_trial['c'] = third_trial.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})
third_trial['Y'] = data['ZipCode']
third_trial.head()
# Out:
#    2000-02-29  2000-03-31  2000-04-30  2000-05-31  2000-06-30  2000-07-31  \
# 0    0.001529    0.001612    0.004157   -0.000874   -0.001428   -0.006510
# 1    0.000700    0.000573    0.000206    0.000641    0.000034   -0.000034
# 2    0.002614    0.002833    0.007165    0.002303    0.000117   -0.001340
# 3    0.000402   -0.000010   -0.000627   -0.000637   -0.000893    0.000000
# 4    0.001167    0.000683    0.004059    0.004786    0.005539    0.001723
#
#    2000-08-31  2000-09-30  2000-10-31  2000-11-30  ...  2021-12-31  \
# 0   -0.001213   -0.003470    0.002664    0.004161  ...    0.014664
# 1   -0.000389   -0.006230   -0.007237   -0.010656  ...    0.010026
# 2    0.000439   -0.000507   -0.001886    0.000359  ...    0.011348
# 3    0.000756    0.001609    0.001126    0.001223  ...    0.025619
# 4   -0.002418   -0.009221   -0.012025   -0.012657  ...    0.011974
#
#    2022-01-31  2022-02-28  2022-03-31  2022-04-30  2022-05-31  2022-06-30  \
# 0    0.014222    0.020819    0.025000    0.029524    0.023412    0.014335
# 1    0.011815    0.011689    0.012228    0.018585    0.019823    0.018659
# 2    0.011645    0.019207    0.023522    0.026851    0.021204    0.012182
# 3    0.026695    0.023237    0.014275    0.014321    0.010969    0.017188
# 4    0.013125    0.012965    0.012570    0.019963    0.020994    0.020287
#
#    cluster        c      Y
# 0        1  #3cb44b  77449
# 1        1  #3cb44b  77494
# 2        1  #3cb44b  79936
# 3        1  #3cb44b  11368
# 4        1  #3cb44b  11385
#
# [5 rows x 272 columns]

# %%
plt.scatter(third_trial['2000-02-29'], third_trial['2022-06-30'],c=third_trial.c, alpha = 0.6, s=10)

# %%
cluster_perf_df['cluster'].value_counts()
# Out:
# cluster  cluster
# 0        0            24
# 1        1          1739
# 2        2          1678
# Name: cluster, dtype: int64

# %% [markdown]
# On performing the third iteration we found that 2 clusters are almost shared divided. Hence, one prominent cluster from iteration 2 itself will become our golden cluster.
